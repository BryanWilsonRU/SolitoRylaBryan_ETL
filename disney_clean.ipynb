# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/disney_plus_raw.csv"
disney_df = pd.read_csv(csv_file)
disney_df.head()
# Out:
#      imdb_id                                       title  \
# 0  tt0147800                  10 Things I Hate About You
# 1  tt7019028                        101 Dalmatian Street
# 2  tt0115433                              101 Dalmatians
# 3  tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4  tt0211181                              102 Dalmatians
#
#                                                 plot    type  rated   year  \
# 0  A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...  series    NaN  2018–
# 2  An evil high-fashion designer plots to steal D...   movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...   movie      G   2000
#
#    released_at           added_at  runtime  \
# 0  31 Mar 1999  November 12, 2019   97 min
# 1  25 Mar 2019  February 28, 2020      NaN
# ...

# %%
disney_df = disney_df[["title", "year"]]
print(len(disney_df))
disney_df
# Out:
# 992
#                                           title   year
# 0                    10 Things I Hate About You   1999
# 1                          101 Dalmatian Street  2018–
# 2                                101 Dalmatians   1996
# 3    101 Dalmatians 2: Patch's London Adventure   2002
# 4                                102 Dalmatians   2000
# ..                                          ...    ...
# 987                                      Zapped   2014
# 988             Zenon: Girl of the 21st Century   1999
# 989                           Zenon: The Zequel   2001
# 990                                   Zenon: Z3   2004
# 991                                    Zootopia   2016
#
# [992 rows x 2 columns]

# %%
csv_file = "Resources/imdb250.csv"
imdb_df = pd.read_csv(csv_file)
imdb_df
# Out:
#      Unnamed: 0  rank         id                              title  year  \
# 0             0     1  tt0111161           The Shawshank Redemption  1994
# 1             1     2  tt0068646                      The Godfather  1972
# 2             2     3  tt0071562             The Godfather: Part II  1974
# 3             3     4  tt0468569                    The Dark Knight  2008
# 4             4     5  tt0050083                       12 Angry Men  1957
# ..          ...   ...        ...                                ...   ...
# 245         245   246  tt0169102  Lagaan: Once Upon a Time in India  2001
# 246         246   247  tt0083922                Fanny and Alexander  1982
# 247         247   248  tt0103639                            Aladdin  1992
# 248         248   249  tt0111495                  Three Colors: Red  1994
# 249         249   250  tt0871510                     Chak de! India  2007
#
#      rating
# 0       9.2
# 1       9.1
# 2       9.0
# 3       9.0
# ...

# %%
imdb_disney = pd.merge(imdb_df, disney_df, on="title")
imdb_disney = imdb_disney[["rank", "id", "title", "rating", "year_x"]]
imdb_disney = imdb_disney.rename(columns={"year_x":"year"})
imdb_disney
# Out:
#     rank         id                                           title  rating  \
# 0     14  tt0080684  Star Wars: Episode V - The Empire Strikes Back     8.7
# 1     25  tt0076759              Star Wars: Episode IV - A New Hope     8.6
# 2     34  tt0110357                                   The Lion King     8.5
# 3     34  tt0110357                                   The Lion King     8.5
# 4     63  tt0910970                                          WALL·E     8.4
# 5     70  tt4154796                               Avengers: Endgame     8.3
# 6     76  tt2380307                                            Coco     8.3
# 7     81  tt0114709                                       Toy Story     8.3
# 8     85  tt0086190      Star Wars: Episode VI - Return of the Jedi     8.3
# 9    103  tt0012349                                         The Kid     8.2
# 10   111  tt0435761                                     Toy Story 3     8.2
# ...

# %%
imdb_disney.describe()
# Out:
#              rank     rating         year
# count   18.000000  18.000000    18.000000
# mean   117.277778   8.261111  1994.277778
# std     80.042493   0.214583    22.220302
# min     14.000000   8.000000  1921.000000
# 25%     64.750000   8.100000  1988.250000
# 50%     94.000000   8.250000  1994.500000
# 75%    167.000000   8.375000  2008.750000
# max    248.000000   8.700000  2019.000000

# %%
imdb_disney.to_csv('Resources/disney_filtered.csv')
